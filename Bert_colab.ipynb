# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install pytorch_transformers
# !pip install tensorboardX
# !pip install pyrouge
#!git clone https://github.com/andersjo/pyrouge.git rouge
# Out:
# ...
#      |████████████████████████████████| 184kB 8.3MB/s
# ...
#      |████████████████████████████████| 870kB 17.1MB/s
# ...
#      |████████████████████████████████| 1.0MB 28.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.38-cp36-none-any.whl size=884628 sha256=152c6157af2ff3aba7d99130361c32149bd63331b51cf3b64b0d1a24453ce91e
#   Stored in directory: /root/.cache/pip/wheels/6d/ec/1a/21b8912e35e02741306f35f66c785f3afe94de754a0eaf1422
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 204kB 8.9MB/s
# ...
#      |████████████████████████████████| 61kB 5.0MB/s
# ...
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-cp36-none-any.whl size=191613 sha256=65cca91602b78f4faf682f76b4084e7843160aa98a347a4c2b7361d7d8ebe573
#   Stored in directory: /root/.cache/pip/wheels/75/d3/0c/e5b04e15b6b87c42e980de3931d2686e14d36e045058983599
# Successfully built pyrouge
# ...

# %%
cd /content/drive/My Drive/PreSumm/src
# Out:
# /content/drive/My Drive/PreSumm/src

# %%
#import torch
#torch.cuda.get_device_name(0)

# %%
#!python train.py  -task abs -mode train -bert_data_path ../bert_data_multilingual/cnndm -dec_dropout 0.2  -model_path ../models/ -sep_optim true -lr_bert 0.002 -lr_dec 0.2 -save_checkpoint_steps 5000 -batch_size 140 -train_steps 30000 -report_every 20 -accum_count 5 -use_bert_emb true -use_interval true -warmup_steps_bert 20000 -warmup_steps_dec 10000 -max_pos 512 -visible_gpus 0 -log_file ../logs/abs_bert_cnndm -train_from ../models/model_step_20000.pt
#!python train.py  -task abs -mode train -bert_data_path ../bert_data_arabic_multilingual/arabic_bert.pt_data -dec_dropout 0.2  -model_path ../models/ -sep_optim true -lr_bert 0.002 -lr_dec 0.2 -save_checkpoint_steps 5000 -batch_size 140 -train_steps 80000 -report_every 20 -accum_count 5 -use_bert_emb true -use_interval true -warmup_steps_bert 20000 -warmup_steps_dec 10000 -max_pos 512 -visible_gpus 0 -log_file ../logs/abs_bert_cnndm  -train_from ../models/model_step_45000.pt
#!python train.py  -task abs -mode train -bert_data_path ../bert_data_arabic_multilingual/arabic_bert.pt_data -dec_dropout 0.2  -model_path ../models/ -sep_optim true -lr_bert 0.002 -lr_dec 0.2 -save_checkpoint_steps 5000 -batch_size 140 -train_steps 25000 -report_every 20 -accum_count 5 -use_bert_emb true -use_interval true -warmup_steps_bert 20000 -warmup_steps_dec 10000 -max_pos 512 -visible_gpus 0 -log_file ../logs/abs_bert_cnndm
# arabic bert ext:
#!python train.py -task ext -mode train -bert_data_path ../bert_data_arabic_multilingual/arabic_bert.pt_data -ext_dropout 0.1 -model_path ../models/ar_bert_ext/ -lr 2e-3 -visible_gpus 0 -report_every 20 -save_checkpoint_steps 5000 -batch_size 2048 -train_steps 50000 -accum_count 2 -log_file ../logs/ar_bert_ext -temp_dir ../temp/ar_bert_ext -use_interval true -warmup_steps 10000 -max_pos 512 -train_from ../models/ar_bert_ext/model_step_25000.pt -train_from ../models/ar_bert_ext/model_step_45000.pt
# arabic bert abs:
#!python train.py -task abs -mode train -bert_data_path ../bert_data_arabic_multilingual/arabic_bert.pt_data -dec_dropout 0.2  -model_path ../models/ar_bert_abs/ -sep_optim true -lr_bert 0.002 -lr_dec 0.2 -save_checkpoint_steps 5000 -batch_size 140 -train_steps 200000 -report_every 20 -accum_count 5 -use_bert_emb true -use_interval true -warmup_steps_bert 20000 -warmup_steps_dec 10000 -max_pos 512 -visible_gpus 0  -log_file ../logs/ar_bert_abs -temp_dir ../temp/ar_bert_abs -train_from ../models/ar_bert_abs/model_step_20000.pt
# arabic base abs:
#!python train.py -task abs -mode train -accum_count 5 -batch_size 300 -bert_data_path ../bert_data_arabic_multilingual/arabic_bert.pt_data -dec_dropout 0.1 -log_file ../logs/ar_base_abs -temp_dir ../temp/ar_base_abs -lr 0.05 -model_path ../models/ar_base_abs/ -save_checkpoint_steps 5000 -sep_optim false -train_steps 200000 -use_bert_emb true -use_interval true -warmup_steps 8000  -visible_gpus 0 -max_pos 512 -report_every 20 -enc_hidden_size 512  -enc_layers 6 -enc_ff_size 2048 -enc_dropout 0.1 -dec_layers 6 -dec_hidden_size 512 -dec_ff_size 2048 -encoder baseline -train_from ../models/ar_base_abs/model_step_10000.pt
# arabic base ext:
# !python train.py -task ext -mode train -accum_count 2 -batch_size 2048 -bert_data_path ../bert_data_arabic_multilingual/arabic_bert.pt_data -dec_dropout 0.1 -log_file ../logs/ar_base_ext -temp_dir ../temp/ar_base_ext -lr 0.05 -model_path ../models/ar_base_ext/ -save_checkpoint_steps 5000 -sep_optim false -train_steps 50000 -use_bert_emb true -use_interval true -warmup_steps 8000  -visible_gpus 0 -max_pos 512 -report_every 20 -enc_hidden_size 512  -enc_layers 6 -enc_ff_size 2048 -enc_dropout 0.1 -dec_layers 6 -dec_hidden_size 512 -dec_ff_size 2048 -encoder baseline
# Out:
# [2020-03-24 23:38:23,809 INFO] Device ID 0
# [2020-03-24 23:38:24,305 INFO] Device cuda
# [2020-03-24 23:38:26,850 INFO] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-config.json from cache at ../temp/ar_base_ext/33b56ce0f312e47e4d77a57791a4fc6233ae4a560dd2bdd186107058294e58ab.c7892120c5a9b21e515abc904e398dbabddf9510b122f659063cbf361fe16868
# [2020-03-24 23:38:27,045 INFO] Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pooler_fc_size": 768,
# ...
